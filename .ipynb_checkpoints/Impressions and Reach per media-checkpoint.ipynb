# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets
import seaborn as sns

# %%
df_initial = pd.read_csv('CJ_Instagram_insights_per_Media_(likes,url,comments_count,date,id_2014_to_2023.csv')

# %%
df_initial.head()
# Out:
#    Unnamed: 0  like_count      media_type  comments_count  \
# 0           0          41           VIDEO               0
# 1           1          11  CAROUSEL_ALBUM               0
# 2           2          43           VIDEO               0
# 3           3           8  CAROUSEL_ALBUM               2
# 4           4          27  CAROUSEL_ALBUM               1
#
#                                            media_url  \
# 0  https://video.cdninstagram.com/o1/v/t16/f1/m82...
# 1  https://scontent.cdninstagram.com/v/t51.29350-...
# 2  https://video.cdninstagram.com/o1/v/t16/f1/m82...
# 3  https://scontent.cdninstagram.com/v/t51.29350-...
# 4  https://scontent.cdninstagram.com/v/t51.29350-...
#
#                   timestamp                 id
# 0  2023-01-24T15:50:58+0000  17953676306238179
# 1  2023-01-08T13:59:28+0000  18337061332062615
# 2  2023-01-03T17:33:44+0000  17884478780780159
# 3  2022-12-01T23:36:34+0000  17944144790302532
# 4  2022-11-15T11:50:54+0000  18267292720097018

# %%
df_initial.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df_initial.head()
# Out:
#    like_count      media_type  comments_count  \
# 0          41           VIDEO               0
# 1          11  CAROUSEL_ALBUM               0
# 2          43           VIDEO               0
# 3           8  CAROUSEL_ALBUM               2
# 4          27  CAROUSEL_ALBUM               1
#
#                                            media_url  \
# 0  https://video.cdninstagram.com/o1/v/t16/f1/m82...
# 1  https://scontent.cdninstagram.com/v/t51.29350-...
# 2  https://video.cdninstagram.com/o1/v/t16/f1/m82...
# 3  https://scontent.cdninstagram.com/v/t51.29350-...
# 4  https://scontent.cdninstagram.com/v/t51.29350-...
#
#                   timestamp                 id
# 0  2023-01-24T15:50:58+0000  17953676306238179
# 1  2023-01-08T13:59:28+0000  18337061332062615
# 2  2023-01-03T17:33:44+0000  17884478780780159
# 3  2022-12-01T23:36:34+0000  17944144790302532
# 4  2022-11-15T11:50:54+0000  18267292720097018

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.figure(figsize=(20, 10))
plt.plot(df_initial['timestamp'], df_initial['like_count'], label='like_count')

plt.plot(df_initial['timestamp'], df_initial['comments_count'], label='comments_count')
plt.title("Line Plot")
plt.xlabel("days")
plt.ylabel("number")
plt.xticks(x[::2])
plt.show()

# %%
df_initial['year'] = pd.to_datetime(df_initial['timestamp']).dt.year
year_dfs = {year: df_initial.loc[df_initial['year'] == year] for year in df_initial['year'].unique()}

# %%
year_dfs[2014]
# Out:
#       like_count media_type  comments_count  \
# 2272          45      IMAGE               1
# 2273          43      IMAGE               3
# 2274          55      IMAGE               1
# 2275          45      IMAGE               0
# 2276          40      IMAGE               2
# ...          ...        ...             ...
# 2873           6      IMAGE               1
# 2874           5      IMAGE               4
# 2875           7      VIDEO               0
# 2876           6      IMAGE               0
# 2877           8      IMAGE               3
#
#                                               media_url  \
# 2272  https://scontent.cdninstagram.com/v/t51.2885-1...
# 2273  https://scontent.cdninstagram.com/v/t51.2885-1...
# 2274  https://scontent.cdninstagram.com/v/t51.2885-1...
# 2275  https://scontent.cdninstagram.com/v/t51.2885-1...
# 2276  https://scontent.cdninstagram.com/v/t51.2885-1...
# ...                                                 ...
# ...

# %%
for k,n in year_dfs.items():
    plt.figure(figsize=(20, 10))
    plt.plot(year_dfs[k]['timestamp'], year_dfs[k]['like_count'], label='like_count')
    plt.plot(year_dfs[k]['timestamp'], year_dfs[k]['comments_count'], label='comments_count')
    plt.title("Line Plot")
    plt.xlabel("days")
    plt.ylabel("number")

    plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-a818019464c9> in <module>()
# ----> 1 y_min = min(df_initial['like_count'].min())
#       2 y_max = max(df_initial['like_count'].max())
#
# TypeError: 'numpy.int64' object is not iterable

# %%
a="https://video.cdninstagram.com/o1/v/t16/f1/m82/654ABEC18D25DD7556F621ECEDAFABAD_video_dashinit.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6InZ0c192b2RfdXJsZ2VuLjEyNzYuY2xpcHMifQ&_nc_ht=video.cdninstagram.com&_nc_cat=111&vs=580720250157745_195538859&_nc_vs=HBksFQIYT2lnX3hwdl9yZWVsc19wZXJtYW5lbnRfcHJvZC82NTRBQkVDMThEMjVERDc1NTZGNjIxRUNFREFGQUJBRF92aWRlb19kYXNoaW5pdC5tcDQVAALIAQAVABgkR01ocWZCTmZyY3VZNUFzQ0FBZmdlWWF1S1N0cmJxX0VBQUFGFQICyAEAKAAYABsBiAd1c2Vfb2lsATEVAAAm2ojKxMOz8UAVAigCQzMsF0BO%2BuFHrhR7GBJkYXNoX2Jhc2VsaW5lXzFfdjERAHUAAA%3D%3D&ccb=9-4&oh=00_AfD6ir3fepVM6r_jLl-fnQkkG8iJCoOy_eLCqHDJ6ipCIg&oe=63D397BD&_nc_sid=ea0b6e&_nc_rid=0a55bbfd65"
len(a)
# Out:
# 633

# %%
df_initial['media_type'].unique()
# Out:
# array(['VIDEO', 'CAROUSEL_ALBUM', 'IMAGE'], dtype=object)

# %%
year_dfs[2014]
# Out:
#       Unnamed: 0  like_count media_type  comments_count  \
# 2272        2272          45      IMAGE               1
# 2273        2273          43      IMAGE               3
# 2274        2274          55      IMAGE               1
# 2275        2275          45      IMAGE               0
# 2276        2276          40      IMAGE               2
# ...          ...         ...        ...             ...
# 2873        2873           6      IMAGE               1
# 2874        2874           5      IMAGE               4
# 2875        2875           7      VIDEO               0
# 2876        2876           6      IMAGE               0
# 2877        2877           8      IMAGE               3
#
#                                               media_url  \
# 2272  https://scontent.cdninstagram.com/v/t51.2885-1...
# 2273  https://scontent.cdninstagram.com/v/t51.2885-1...
# 2274  https://scontent.cdninstagram.com/v/t51.2885-1...
# 2275  https://scontent.cdninstagram.com/v/t51.2885-1...
# ...

# %%
df_2021= year_dfs[2021]
df_2022 =year_dfs[2022]

# %%
year_dfs[2023]
# Out:
#    like_count      media_type  comments_count  \
# 0          41           VIDEO               0
# 1          11  CAROUSEL_ALBUM               0
# 2          43           VIDEO               0
#
#                                            media_url  \
# 0  https://video.cdninstagram.com/o1/v/t16/f1/m82...
# 1  https://scontent.cdninstagram.com/v/t51.29350-...
# 2  https://video.cdninstagram.com/o1/v/t16/f1/m82...
#
#                   timestamp                 id  year
# 0  2023-01-24T15:50:58+0000  17953676306238179  2023
# 1  2023-01-08T13:59:28+0000  18337061332062615  2023
# 2  2023-01-03T17:33:44+0000  17884478780780159  2023

# %%
df_2021['month'] = pd.to_datetime(df_2021['timestamp']).dt.month
month_2021_dfs = {month: df_2021.loc[df_2021['month'] == month] for month in df_2021['month'].unique()}
# Out:
# /home/ledjinn/miniconda3/envs/6.86x/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
for k in range(1,13):
    print(f' for month {k} the sum of like is:{month_2021_dfs[k]["like_count"].sum()}')
# Out:
#  for month 1 the sum of like is:222
#  for month 2 the sum of like is:105
#  for month 3 the sum of like is:107
#  for month 4 the sum of like is:102
#  for month 5 the sum of like is:129
#  for month 6 the sum of like is:73
#  for month 7 the sum of like is:131
#  for month 8 the sum of like is:268
#  for month 9 the sum of like is:152
#  for month 10 the sum of like is:217
#  for month 11 the sum of like is:144
#  for month 12 the sum of like is:115

# %%
df_2022['month'] = pd.to_datetime(df_2022['timestamp']).dt.month
month_2022_dfs = {month: df_2022.loc[df_2022['month'] == month] for month in df_2022['month'].unique()}
# Out:
# /home/ledjinn/miniconda3/envs/6.86x/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
for k in range(1,13):
    print(f' for month {k} the sum of like is:{month_2022_dfs[k]["like_count"].sum()}')
# Out:
#  for month 1 the sum of like is:286
#  for month 2 the sum of like is:60
#  for month 3 the sum of like is:65
#  for month 4 the sum of like is:68
#  for month 5 the sum of like is:56
#  for month 6 the sum of like is:55
#  for month 7 the sum of like is:33
#  for month 8 the sum of like is:33
#  for month 9 the sum of like is:75
#  for month 10 the sum of like is:156
#  for month 11 the sum of like is:2149
#  for month 12 the sum of like is:8

# %%
for k in range(1,13):
    print(f' for month {k} the sum of comment is:{month_2021_dfs[k]["comments_count"].sum()}')
# Out:
#  for month 1 the sum of comment is:1
#  for month 2 the sum of comment is:1
#  for month 3 the sum of comment is:1
#  for month 4 the sum of comment is:3
#  for month 5 the sum of comment is:3
#  for month 6 the sum of comment is:1
#  for month 7 the sum of comment is:5
#  for month 8 the sum of comment is:10
#  for month 9 the sum of comment is:0
#  for month 10 the sum of comment is:4
#  for month 11 the sum of comment is:4
#  for month 12 the sum of comment is:4

# %%
for k in range(1,13):
    print(f' for month {k} the sum of comment is:{month_2022_dfs[k]["comments_count"].sum()}')
# Out:
#  for month 1 the sum of comment is:7
#  for month 2 the sum of comment is:7
#  for month 3 the sum of comment is:3
#  for month 4 the sum of comment is:2
#  for month 5 the sum of comment is:1
#  for month 6 the sum of comment is:3
#  for month 7 the sum of comment is:2
#  for month 8 the sum of comment is:0
#  for month 9 the sum of comment is:6
#  for month 10 the sum of comment is:4
#  for month 11 the sum of comment is:20
#  for month 12 the sum of comment is:2

# %%
df_global= pd.read_csv('impressions_reach_CJ_instagram_21-2-7_to_23-1-24_corected_version.csv')

# %%
df_global.head()
# Out:
#    Unnamed: 0  impressions        date  reach
# 0           0         1438  2021-02-07   1294
# 1           1         1195  2021-02-08   1078
# 2           2          451  2021-02-09    348
# 3           3          108  2021-02-10     99
# 4           4          163  2021-02-11     31

# %%
df_global['year'] = pd.to_datetime(df_global['date']).dt.year
year_dfs_global = {year: df_global.loc[df_global['year'] == year] for year in df_global['year'].unique()}

# %%
df_global_2021=year_dfs_global[2021]
df_global_2022=year_dfs_global[2022]

# %%
df_global_2021.shape
# Out:
# (282, 5)

# %%
df_global_2021['month'] = pd.to_datetime(df_global_2021['date']).dt.month
month_global_2021_dfs = {month: df_global_2021.loc[df_global_2021['month'] == month] for month in df_global_2021['month'].unique()}
# Out:
# /home/ledjinn/miniconda3/envs/6.86x/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_global_2022['month'] = pd.to_datetime(df_global_2022['date']).dt.month
month_global_2022_dfs = {month: df_global_2022.loc[df_global_2022['month'] == month] for month in df_global_2022['month'].unique()}
# Out:
# /home/ledjinn/miniconda3/envs/6.86x/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
for k in range(1,13):
    print(f' for month {k} the sum of impressions is:{month_global_2022_dfs[k]["impressions"].sum()}')
# Out:
#  for month 1 the sum of impressions is:10944
#  for month 2 the sum of impressions is:3829
#  for month 3 the sum of impressions is:5878
#  for month 4 the sum of impressions is:4154
#  for month 5 the sum of impressions is:3972
#  for month 6 the sum of impressions is:2353
#  for month 7 the sum of impressions is:2712
#  for month 8 the sum of impressions is:3651
#  for month 9 the sum of impressions is:6249
#  for month 10 the sum of impressions is:9667
#  for month 11 the sum of impressions is:25047
#  for month 12 the sum of impressions is:4976

# %%
for k in range(2,13):
    print(f' for month {k} the sum of impressions is:{month_global_2021_dfs[k]["reach"].sum()}')
# Out:
#  for month 2 the sum of impressions is:6245
#  for month 3 the sum of impressions is:5689
#  for month 4 the sum of impressions is:7171
#  for month 5 the sum of impressions is:9357
#  for month 6 the sum of impressions is:4548
#  for month 7 the sum of impressions is:6284
#  for month 8 the sum of impressions is:10175
#  for month 9 the sum of impressions is:7501
#  for month 10 the sum of impressions is:7698
#  for month 11 the sum of impressions is:5960
#  for month 12 the sum of impressions is:5548

# %%
for k in range(1,13):
    print(month_global_2022_dfs[k]["reach"].sum())
# Out:
# 7533
# 2796
# 3910
# 3249
# 2673
# 1401
# 1710
# 2367
# 5022
# 7207
# 20599
# 3795

# %%
df_global.[]
# Out:
#   File "<ipython-input-112-1f3df9d8e180>", line 1
#     df_global.[]
#               ^
# SyntaxError: invalid syntax

# %%
df_media_global=pd.read_csv('CJ_Instagram_insights_per_Media_(likes,url,comments_count,date,id_2014_to_2023.csv')

# %%
df_media_global.shape
# Out:
# (2878, 7)

# %%
df_media_global['timestamp']=pd.to_datetime(df_media_global['timestamp'])

# %%
df_media_global = df_media_global[df_media_global['timestamp'] > '2021-01-01']

# %%
df_media_global['id'][95]
# Out:
# 17881702316462142

# %%
import requests

# %%
def fetch_data_media(media_id):
    token='EAAmNvp7ZCK7kBAHg1fpfphuI5mN2dmgtFKEZCSWf41LlFpZANRq3N8CV1hOwRiE1I6QYEhCkmHgE4hwDBEAqwuUtlu8RkFTxzkMbFXk6OIRwr3gR4v1wdtZAjv0xhYxIsGEki3BxL0u0rtmDvug4l16GMdfZC427I6opiRJTdbZCI0852dsWSAb9BYhJ2KcigZD'
    url= f'https://graph.facebook.com/v15.0/{media_id}/insights/reach,impressions/lifetime?access_token=EAAmNvp7ZCK7kBAHg1fpfphuI5mN2dmgtFKEZCSWf41LlFpZANRq3N8CV1hOwRiE1I6QYEhCkmHgE4hwDBEAqwuUtlu8RkFTxzkMbFXk6OIRwr3gR4v1wdtZAjv0xhYxIsGEki3BxL0u0rtmDvug4l16GMdfZC427I6opiRJTdbZCI0852dsWSAb9BYhJ2KcigZD'
    r = requests.get(url)
    json=r.json()
    return json

# %%
media_data_reach_values=[]
for d in df_media_global['id']:
    media_data_reach_values.append(fetch_data_media(d))

# %%
data=fetch_data_media(df_media_global['id'][95])

# %%
len(media_data_reach_values)
# Out:
# 133

# %%
array_medias_reach=[]
for d in media_data_reach_values:
    if 'data' in d:
            obj_data = {'reach': d['data'][0]['values'][0]['value'],
                     'impressions' : d['data'][1]['values'][0]['value'],
                   'id': d['data'][1]['id']}
            array_medias_reach.append(obj_data)
    else:
        obj_data = {'reach': 0,
                          'impressions' : 0,
                         'id': d}

# %%
array_medias_reach
# Out:
# [{'reach': 533,
#   'impressions': 643,
#   'id': '18337061332062615/insights/impressions/lifetime'},
#  {'reach': 465,
#   'impressions': 566,
#   'id': '17944144790302532/insights/impressions/lifetime'},
#  {'reach': 789,
#   'impressions': 991,
#   'id': '18267292720097018/insights/impressions/lifetime'},
#  {'reach': 22489,
#   'impressions': 27792,
#   'id': '17966325259964589/insights/impressions/lifetime'},
#  {'reach': 778,
#   'impressions': 968,
#   'id': '18190075591230780/insights/impressions/lifetime'},
#  {'reach': 1990,
#   'impressions': 2447,
#   'id': '17867245325766907/insights/impressions/lifetime'},
#  {'reach': 2328,
#   'impressions': 2480,
#   'id': '17948561087336576/insights/impressions/lifetime'},
#  {'reach': 599,
#   'impressions': 710,
#   'id': '17964334879865504/insights/impressions/lifetime'},
#  {'reach': 723,
#   'impressions': 854,
#   'id': '18010157944470510/insights/impressions/lifetime'},
#  {'reach': 516,
#   'impressions': 559,
# ...

# %%
df = pd.DataFrame(array_medias_reach)

# %%
len('insights/impressions/lifetime')
# Out:
# 29

# %%
df['id']=[str(date)[:-1] for date in df['id']]

# %%
df['id']
# Out:
# 0      18337061332062615
# 1      17944144790302532
# 2      18267292720097018
# 3      17966325259964589
# 4      18190075591230780
#              ...
# 124    17957746069375720
# 125    18189910783061233
# 126    17956524367385651
# 127    17860701923343104
# 128    17900674462681317
# Name: id, Length: 129, dtype: object

# %%
df['id']=df['id'].astype(int)

# %%
df=df.set_index('id')

# %%
df_initial=df_initial.set_index('id')

# %%
big_df = df_initial.merge(df, on='id', how='left')

# %%
big_df
# Out:
#                    like_count      media_type  comments_count  \
# id
# 17953676306238179          41           VIDEO               0
# 18337061332062615          11  CAROUSEL_ALBUM               0
# 17884478780780159          43           VIDEO               0
# 17944144790302532           8  CAROUSEL_ALBUM               2
# 18267292720097018          27  CAROUSEL_ALBUM               1
# ...                       ...             ...             ...
# 17842843936063381           6           IMAGE               1
# 17842842853063381           5           IMAGE               4
# 17842842415063381           7           VIDEO               0
# 17842798006063381           6           IMAGE               0
# 17841931498063381           8           IMAGE               3
#
#                                                            media_url  \
# id
# 17953676306238179  https://video.cdninstagram.com/o1/v/t16/f1/m82...
# 18337061332062615  https://scontent.cdninstagram.com/v/t51.29350-...
# ...

# %%
big_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c0d8d5ca7dbb> in <module>()
# ----> 1 big_df
#
# NameError: name 'big_df' is not defined

# %%
result_clean=big_df.dropna()

# %%
result_clean
# Out:
#                    like_count      media_type  comments_count  \
# id
# 18337061332062615          11  CAROUSEL_ALBUM               0
# 17944144790302532           8  CAROUSEL_ALBUM               2
# 18267292720097018          27  CAROUSEL_ALBUM               1
# 17966325259964589        1981  CAROUSEL_ALBUM               9
# 18190075591230780          47  CAROUSEL_ALBUM               3
# ...                       ...             ...             ...
# 17957746069375720          25           IMAGE               0
# 18189910783061233          24           IMAGE               0
# 17956524367385651          10           IMAGE               0
# 17860701923343104          20           IMAGE               0
# 17900674462681317          20           IMAGE               0
#
#                                                            media_url  \
# id
# 18337061332062615  https://scontent.cdninstagram.com/v/t51.29350-...
# 17944144790302532  https://scontent.cdninstagram.com/v/t51.29350-...
# ...

# %%
result_clean['year'] = pd.to_datetime(result_clean['timestamp']).dt.year
year_dfs_meidas = {year: result_clean.loc[result_clean['year'] == year] for year in result_clean['year'].unique()}
# Out:
# /home/ledjinn/miniconda3/envs/6.86x/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_full_2021=year_dfs_meidas[2021]
df_full_2022=year_dfs_meidas[2022]

# %%
df_full_2021
# Out:
#     like_count      media_type  comments_count  \
# 51          18  CAROUSEL_ALBUM               1
# 52          13  CAROUSEL_ALBUM               1
# 53          25           IMAGE               1
# 54          14           IMAGE               1
# 55          13           IMAGE               0
# 56          32           IMAGE               0
# 57          12           IMAGE               0
# 58          25           IMAGE               0
# 59          20  CAROUSEL_ALBUM               0
# 60          10           VIDEO               0
# 61          12           IMAGE               0
# 62          15           IMAGE               2
# 63          24  CAROUSEL_ALBUM               0
# 64          12           VIDEO               2
# 65          14           IMAGE               0
# 66         114           IMAGE               3
# 67          26  CAROUSEL_ALBUM               0
# 68           3           IMAGE               0
# 69          18           IMAGE               0
# ...

# %%
df_full_2021['month'] = pd.to_datetime(df_full_2021['timestamp']).dt.month
month_media_2021_dfs = {month: df_full_2021.loc[df_full_2021['month'] == month] for month in df_full_2021['month'].unique()}
# Out:
# /home/ledjinn/miniconda3/envs/6.86x/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
month_media_2021_dfs
# Out:
# {12:     like_count      media_type  comments_count  \
#  51          18  CAROUSEL_ALBUM               1
#  52          13  CAROUSEL_ALBUM               1
#  53          25           IMAGE               1
#  54          14           IMAGE               1
#  55          13           IMAGE               0
#  56          32           IMAGE               0
#
#                                              media_url  \
#  51  https://scontent.cdninstagram.com/v/t51.29350-...
#  52  https://scontent.cdninstagram.com/v/t51.29350-...
#  53  https://scontent.cdninstagram.com/v/t51.29350-...
#  54  https://scontent.cdninstagram.com/v/t51.29350-...
#  55  https://scontent.cdninstagram.com/v/t51.29350-...
#  56  https://scontent.cdninstagram.com/v/t51.29350-...
#
#                     timestamp                 id  year   reach  impressions  \
#  51  2021-12-21T18:27:22+0000  17871377519586936  2021   650.0        786.0
#  52  2021-12-20T12:39:36+0000  17904522077268898  2021   560.0        701.0
# ...

# %%
for k in range(1,13):
    print(f' for month {k} the sum of impressions is:{month_media_2021_dfs[k]["impressions"].sum()}')
# Out:
#  for month 1 the sum of impressions is:1432.0
#  for month 2 the sum of impressions is:671.0
#  for month 3 the sum of impressions is:5641.0
#  for month 4 the sum of impressions is:6883.0
#  for month 5 the sum of impressions is:10287.0
#  for month 6 the sum of impressions is:4481.0
#  for month 7 the sum of impressions is:7384.0
#  for month 8 the sum of impressions is:13202.0
#  for month 9 the sum of impressions is:6855.0
#  for month 10 the sum of impressions is:9396.0
#  for month 11 the sum of impressions is:6243.0
#  for month 12 the sum of impressions is:4692.0

# %%
df_full_2022['month'] = pd.to_datetime(df_full_2022['timestamp']).dt.month
month_media_2022_dfs = {month: df_full_2022.loc[df_full_2022['month'] == month] for month in df_full_2022['month'].unique()}
# Out:
# /home/ledjinn/miniconda3/envs/6.86x/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
for k in range(1,13):
    print(f' for month {k} the sum of impressions is:{month_media_2022_dfs[k]["reach"].sum()}')
# Out:
#  for month 1 the sum of impressions is:7309.0
#  for month 2 the sum of impressions is:1992.0
#  for month 3 the sum of impressions is:2490.0
#  for month 4 the sum of impressions is:1832.0
#  for month 5 the sum of impressions is:2187.0
#  for month 6 the sum of impressions is:1624.0
#  for month 7 the sum of impressions is:1050.0
#  for month 8 the sum of impressions is:1681.0
#  for month 9 the sum of impressions is:4208.0
#  for month 10 the sum of impressions is:6950.0
#  for month 11 the sum of impressions is:26046.0
#  for month 12 the sum of impressions is:465.0
